# %%
import pandas as pd 
import matplotlib.pyplot as plt

from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans

# %%
df = pd.read_csv('data.csv', index_col='id')##.dropna()
df['genre'] = df['genre'].str.split(',')
df
# Out:
#                                                    title  \
# id
# 0                                            The Martian
# 1      Under the Banner of Heaven: A Story of Violent...
# 2                                      Cutting for Stone
# 3                            We Need to Talk About Kevin
# 4                   The Immortal Life of Henrietta Lacks
# ...                                                  ...
# 10013            Edge of Passion (Stealth Guardians, #1)
# 10014  Tales from a Not-So-Popular Party Girl (Dork D...
# 10015                                            Bottoms
# 10016                                  The Wedding Dress
# 10017  The Immortal Hunter (Argeneau #11; Rogue Hunte...
#
#                                    series                author  \
# id
# 0            \n        (The Martian #1)\n             Andy Weir
# 1                                     NaN          Jon Krakauer
# 2                                     NaN    Abraham   Verghese
# ...

# %%
df1 = df.copy()

# print(type(df1['genre'][0]) == pd.list)
# print(df1['genre'][0] )

for i in range(10018):
    # print(type(df1['genre'][i])==list)
    # if(type(df1['genre'][i])==list
    try:
        if('Science' not in df1['genre'][i]):
            df1 = df1.drop(i)
    except:
        continue
    # else:
    #     continue
    
# df1
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[77], line 3
#       1 df1 = df.copy()
# ----> 3 print(type(df1['genre'][0]) == pd.list)
#       4 # print(df1['genre'][0] )
#       6 for i in range(10018):
#       7     # print(type(df1['genre'][i])==list)
#       8     # if(type(df1['genre'][i])==list
#
# File c:\Users\fazas\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\__init__.py:264, in __getattr__(name)
#     260     from pandas.core.arrays.sparse import SparseArray as _SparseArray
#     262     return _SparseArray
# --> 264 raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#
# AttributeError: module 'pandas' has no attribute 'list'

# %%
# Out:
# list
